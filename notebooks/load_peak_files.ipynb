# %%
import os
import numpy as np

# %%
# Define the directory where the processed L1 norm files are stored
base_dir = "/home/tersenov/CosmoGridV1/stage3_forecast/grid/"

# Collect all the expected L1 norm filenames
peak_files = []
missing_files = []

# %% [markdown]
# ## Test

# %% [markdown]
# ### Grid

# %%
all_peaks = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/new_grid/all_peak_counts_grid_nobaryons_bin3_noisy_s0.26_new_normalization.npy')

# %%
all_peaks.shape
# Out:
# (16965, 5, 40)

# %%
import matplotlib.pyplot as plt
for j in range(5):
    for i in range(16965):
        plt.plot(all_peaks[i][j], alpha=0.1)
    plt.yscale('log')
    plt.show()
# Out:
# /tmp/ipykernel_3965825/1481637596.py:5: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')

# %%
import matplotlib.pyplot as plt
for j in range(5):
    for i in range(16965):
        plt.plot(all_peaks[i][j], alpha=0.1)
    plt.yscale('log')
    plt.show()

# %% [markdown]
# ### Fiducial

# %%
fid_full = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/fiducial/cosmo_fiducial/all_peak_counts_fiducial_nobaryons_bin1_noisy_s0.26_new_normalization.npy', allow_pickle=True)

# %%
fid_full.shape
# Out:
# (200, 5, 40)

# %%
fid_mean = np.mean(fid_full, axis=0)
fid_mean.shape
# Out:
# (5, 40)

# %%
import matplotlib.pyplot as plt
for j in range(5):
    for i in range(200):
        plt.plot(fid_full[i,j], alpha=0.1)
    plt.yscale('log')
    plt.title(f"Peak Count - Scale {j}")
    plt.show()
# Out:
# /tmp/ipykernel_1259004/3149410103.py:5: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')

# %%
import matplotlib.pyplot as plt
for i in range(16962):
    plt.plot(all_peaks[i][0], alpha=0.1)
plt.plot(fid_mean[0], label='Peak Fiducial', linestyle='--', color='k')
plt.yscale('log')

# %% [markdown]
# ### Test one-by-one

# %%
plt.plot(all_l1_norms[16965, 1, :], label='L1 Norm')
plt.plot(all_l1_norms_auto[16965, 1, :], label='L1 Norm Auto', linestyle='--')

# %% [markdown]
# ## Fiducial

# %%
import os
import numpy as np

# Define the directory where the processed L1 norm files are stored
base_dir = "/home/tersenov/CosmoGridV1/stage3_forecast/fiducial/cosmo_fiducial/"

# Collect all the expected L1 norm filenames
l1_norm_files = []
missing_files = []

# %%
all_l1_norms_bin1 = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/fiducial/cosmo_fiducial/all_l1_norms_fiducial_nobaryons_bin1_noisy_s0.26_new_normalization.npy', allow_pickle=True)
all_l1_norms_bin2 = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/fiducial/cosmo_fiducial/all_l1_norms_fiducial_nobaryons_bin2_noisy_s0.26_new_normalization.npy', allow_pickle=True)
all_l1_norms_bin3 = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/fiducial/cosmo_fiducial/all_l1_norms_fiducial_nobaryons_bin3_noisy_s0.26_new_normalization.npy', allow_pickle=True)
all_l1_norms_bin4 = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/fiducial/cosmo_fiducial/all_l1_norms_fiducial_nobaryons_bin4_noisy_s0.26_new_normalization.npy', allow_pickle=True)

# %%
all_l1_norms_bin1.shape, all_l1_norms_bin2.shape, all_l1_norms_bin3.shape, all_l1_norms_bin4.shape
# Out:
# ((200, 5, 40), (200, 5, 40), (200, 5, 40), (200, 5, 40))

# %%
import matplotlib.pyplot as plt

for i in range(5):
    plt.plot(all_l1_norms_bin1[100,i])
plt.show()

for i in range(5):
    plt.plot(all_l1_norms_bin2[11,i])
plt.show()

for i in range(5):
    plt.plot(all_l1_norms_bin3[11,i])
plt.show()

for i in range(5):
    plt.plot(all_l1_norms_bin4[11,i])
plt.show()

# %% [markdown]
# ## BNT

# %% [markdown]
# ### Grid

# %%
all_peaks = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/new_grid/all_bnt_peak_counts_grid_nobaryons_bin3_noisy_s0.26_new_normalization.npy')

# %%
all_peaks.shape
# Out:
# (16965, 5, 40)

# %%
import matplotlib.pyplot as plt
for j in range(5):
    for i in range(16965):
        plt.plot(all_peaks[i][j], alpha=0.1)
    plt.yscale('log')
    plt.show()
# Out:
# /tmp/ipykernel_1856725/1481637596.py:5: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')

# %% [markdown]
# ### Fiducial

# %%
fid_full_bnt = np.load('/home/tersenov/CosmoGridV1/stage3_forecast/fiducial/cosmo_fiducial/all_bnt_peak_counts_fiducial_nobaryons_bin3_noisy_s0.26_new_normalization.npy', allow_pickle=True)

# %%
fid_full_bnt.shape
# Out:
# (200, 5, 40)

# %%
fid_mean_bnt = np.mean(fid_full_bnt, axis=0)
fid_mean_bnt.shape
# Out:
# (5, 40)

# %%
import matplotlib.pyplot as plt
for j in range(5):
    for i in range(200):
        plt.plot(fid_full_bnt[i,j], alpha=0.1)
    plt.yscale('log')
    plt.title(f"Peak Count - Scale {j}")
    plt.show()
# Out:
# /tmp/ipykernel_1856725/934725647.py:5: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')

# %%
import matplotlib.pyplot as plt
for i in range(16962):
    plt.plot(all_peaks[i][0], alpha=0.1)
plt.plot(fid_mean_bnt[0], label='Peak Fiducial', linestyle='--', color='k')
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
for j in range(5):
    for i in range(16965):
        plt.plot(all_peaks[i][j], alpha=0.1)
    plt.plot(fid_mean_bnt[j], label='Peak Fiducial', linestyle='--', color='k')
    plt.yscale('log')
    plt.title(f"Peak Count - Scale {j}")
    plt.show()
# Out:
# /tmp/ipykernel_1856725/535682194.py:6: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')
