# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
# %matplotlib inline

# %% [markdown]
# # Unbiased contours

# %% [markdown]
# ## No bar, noisy, different bins

# %% [markdown]
# ### Bin 1, scale 1: old vs new

# %%
samples_bin1_sc1_old = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobar_scale1_bin1_noisy_s026_npe.npy')
samples_bin1_sc1_new = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc1_old = MCSamples(
    samples=samples_bin1_sc1_old,
    names=labels,
    label="NoBar, bin1, scale1, OLD",
)
samples_bin1_sc1_new = MCSamples(
    samples=samples_bin1_sc1_new,
    names=labels,
    label="NoBar, bin1, scale1, NEW",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc1_old, samples_bin1_sc1_new],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale 1

# %%
# samples_bin1_sc1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobar_scale1_bin1_noisy_s026_npe.npy')
samples_bin1_sc1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scale1_noisy_s0.26_npe.npy')
samples_bin2_sc1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale1_noisy_s0.26_npe.npy')
samples_bin3_sc1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scale1_noisy_s0.26_npe.npy')
samples_bin4_sc1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin4_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc1 = MCSamples(
    samples=samples_bin1_sc1,
    names=labels,
    label="NoBar, bin1, scale1",
)
samples_bin2_sc1 = MCSamples(
    samples=samples_bin2_sc1,
    names=labels,
    label="NoBar, bin2, scale1",
)
samples_bin3_sc1 = MCSamples(
    samples=samples_bin3_sc1,
    names=labels,
    label="NoBar, bin3, scale1",
)
samples_bin4_sc1 = MCSamples(
    samples=samples_bin4_sc1,
    names=labels,
    label="NoBar, bin4, scale1",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc1, samples_bin2_sc1, samples_bin3_sc1, samples_bin4_sc1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale 2

# %%
samples_bin1_sc2 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scale2_noisy_s0.26_npe.npy')
samples_bin2_sc2 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale2_noisy_s0.26_npe.npy')
samples_bin3_sc2 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scale2_noisy_s0.26_npe.npy')
samples_bin4_sc2 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin4_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc2 = MCSamples(
    samples=samples_bin1_sc2,
    names=labels,
    label="NoBar, bin1, scale2",
)
samples_bin2_sc2 = MCSamples(
    samples=samples_bin2_sc2,
    names=labels,
    label="NoBar, bin2, scale2",
)
samples_bin3_sc2 = MCSamples(
    samples=samples_bin3_sc2,
    names=labels,
    label="NoBar, bin3, scale2",
)
samples_bin4_sc2 = MCSamples(
    samples=samples_bin4_sc2,
    names=labels,
    label="NoBar, bin4, scale2",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc2, samples_bin2_sc2, samples_bin3_sc2, samples_bin4_sc2],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
# OLD BIN 1
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc2, samples_bin2_sc2, samples_bin3_sc2, samples_bin4_sc2],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Bar, noisy, different bins

# %% [markdown]
# ## OLD

# %% [markdown]
# ### Scale 1

# %%
samples_bin1_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale1_bin1_noisy_s026_npe.npy')
samples_bin2_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale1_bin2_noisy_s026_npe.npy')
samples_bin3_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale1_bin3_noisy_s026_npe.npy')
samples_bin4_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale1_bin4_noisy_s026_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc1_bar = MCSamples(
    samples=samples_bin1_sc1_bar,
    names=labels,
    label="Bar, bin1, scale1",
)
samples_bin2_sc1_bar = MCSamples(
    samples=samples_bin2_sc1_bar,
    names=labels,
    label="Bar, bin2, scale1",
)
samples_bin3_sc1_bar = MCSamples(
    samples=samples_bin3_sc1_bar,
    names=labels,
    label="Bar, bin3, scale1",
)
samples_bin4_sc1_bar = MCSamples(
    samples=samples_bin4_sc1_bar,
    names=labels,
    label="Bar, bin4, scale1",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc1_bar, samples_bin2_sc1_bar, samples_bin3_sc1_bar, samples_bin4_sc1_bar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## NEW

# %% [markdown]
# ### Scale 1

# %%
samples_bin1_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin1_scale1_noisy_s0.26_npe.npy')
samples_bin2_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin2_scale1_noisy_s0.26_npe.npy')
samples_bin3_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin3_scale1_noisy_s0.26_npe.npy')
samples_bin4_sc1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin4_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc1_bar = MCSamples(
    samples=samples_bin1_sc1_bar,
    names=labels,
    label="Bar, bin1, scale1",
)
samples_bin2_sc1_bar = MCSamples(
    samples=samples_bin2_sc1_bar,
    names=labels,
    label="Bar, bin2, scale1",
)
samples_bin3_sc1_bar = MCSamples(
    samples=samples_bin3_sc1_bar,
    names=labels,
    label="Bar, bin3, scale1",
)
samples_bin4_sc1_bar = MCSamples(
    samples=samples_bin4_sc1_bar,
    names=labels,
    label="Bar, bin4, scale1",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc1_bar, samples_bin2_sc1_bar, samples_bin3_sc1_bar, samples_bin4_sc1_bar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale 2

# %%
samples_bin1_sc2_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin1_scale2_noisy_s0.26_npe.npy')
samples_bin2_sc2_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin2_scale2_noisy_s0.26_npe.npy')
samples_bin3_sc2_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin3_scale2_noisy_s0.26_npe.npy')
samples_bin4_sc2_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin4_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc2_bar = MCSamples(
    samples=samples_bin1_sc2_bar,
    names=labels,
    label="Bar, bin1, scale2",
)
samples_bin2_sc2_bar = MCSamples(
    samples=samples_bin2_sc2_bar,
    names=labels,
    label="Bar, bin2, scale2",
)
samples_bin3_sc2_bar = MCSamples(
    samples=samples_bin3_sc2_bar,
    names=labels,
    label="Bar, bin3, scale2",
)
samples_bin4_sc2_bar = MCSamples(
    samples=samples_bin4_sc2_bar,
    names=labels,
    label="Bar, bin4, scale2",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc2_bar, samples_bin2_sc2_bar, samples_bin3_sc2_bar, samples_bin4_sc2_bar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin4_sc2_bar, samples_bin4_sc2],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Biased contours

# %% [markdown]
# ## Bin 1

# %% [markdown]
# ### Scale 1

# %%
samples_bin1_sc1_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin1_scale1_noisy_s0.26_npe.npy')
samples_bin1_sc1_biased   = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin1_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc1_unbiased = MCSamples(
    samples=samples_bin1_sc1_unbiased,
    names=labels,
    label="Unbiased, bin1, scale1",
)
samples_bin1_sc1_biased = MCSamples(
    samples=samples_bin1_sc1_biased,
    names=labels,
    label="Biased, bin1, scale1",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc1_unbiased, samples_bin1_sc1_biased],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale 2

# %%
samples_bin1_sc2_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin1_scale2_noisy_s0.26_npe.npy')
samples_bin1_sc2_biased   = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin1_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc2_unbiased = MCSamples(
    samples=samples_bin1_sc2_unbiased,
    names=labels,
    label="Unbiased, bin1, scale2",
)
samples_bin1_sc2_biased = MCSamples(
    samples=samples_bin1_sc2_biased,
    names=labels,
    label="Biased, bin1, scale2",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc2_unbiased, samples_bin1_sc2_biased],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Bin 2

# %% [markdown]
# ### Scale 1

# %%
# samples_bin2_sc1_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale1_bin2_noisy_s026_npe.npy')
samples_bin2_sc1_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin2_scale1_noisy_s0.26_npe.npy')
samples_bin2_sc1_biased   = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin2_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin2_sc1_unbiased = MCSamples(
    samples=samples_bin2_sc1_unbiased,
    names=labels,
    label="Unbiased, bin2, scale1",
)
samples_bin2_sc1_biased = MCSamples(
    samples=samples_bin2_sc1_biased,
    names=labels,
    label="Biased, bin2, scale1",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin2_sc1_unbiased, samples_bin2_sc1_biased],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin2_sc1_unbiased, samples_bin2_sc1_biased],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale 2

# %%
# samples_bin2_sc2_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale2_bin2_noisy_s026_npe.npy')
# samples_bin2_sc2_biased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin2_scale2_noisy_s0.26_npe.npy')

# samples_bin2_sc2_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale2_bin2_noisy_s026_npe.npy')
# samples_bin2_sc2_biased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin2_scale2_noisy_s0.26_npe.npy')

samples_bin2_sc2_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin2_scale2_noisy_s0.26_npe.npy')
samples_bin2_sc2_biased   = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin2_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin2_sc2_unbiased = MCSamples(
    samples=samples_bin2_sc2_unbiased,
    names=labels,
    label="Unbiased, bin2, scale2",
)
samples_bin2_sc2_biased = MCSamples(
    samples=samples_bin2_sc2_biased,
    names=labels,
    label="Biased, bin2, scale2",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin2_sc2_unbiased, samples_bin2_sc2_biased],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Bin 4

# %% [markdown]
# ### Scale 1

# %%
# samples_bin4_sc1_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale1_bin4_noisy_s026_npe.npy')
# samples_bin4_sc1_biased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin4_scale1_noisy_s0.26_npe.npy')

samples_bin4_sc1_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin4_scale1_noisy_s0.26_npe.npy')
samples_bin4_sc1_biased   = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin4_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin4_sc1_unbiased = MCSamples(
    samples=samples_bin4_sc1_unbiased,
    names=labels,
    label="Unbiased, bin4, scale1",
)
samples_bin4_sc1_biased = MCSamples(
    samples=samples_bin4_sc1_biased,
    names=labels,
    label="Biased, bin4, scale1",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin4_sc1_unbiased, samples_bin4_sc1_biased],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale 2

# %%
# samples_bin4_sc2_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bar_scale2_bin4_noisy_s026_npe.npy')
# samples_bin4_sc2_biased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin4_scale2_noisy_s0.26_npe.npy')

samples_bin4_sc2_unbiased = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_baryonified_vs_baryonified_bin4_scale2_noisy_s0.26_npe.npy')
samples_bin4_sc2_biased   = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bin4_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin4_sc2_unbiased = MCSamples(
    samples=samples_bin4_sc2_unbiased,
    names=labels,
    label="Unbiased, bin4, scale2",
)
samples_bin4_sc2_biased = MCSamples(
    samples=samples_bin4_sc2_biased,
    names=labels,
    label="Biased, bin4, scale2",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin4_sc2_unbiased, samples_bin4_sc2_biased],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Noisy vs noiseless (Bin 2)

# %% [markdown]
# ### Scale1

# %%
samples_bin2_sc1_noisy = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale1_noisy_s0.26_npe.npy')
samples_bin2_sc1_noisy044 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale1_noisy_s0.44_npe.npy')
samples_bin2_sc1_noiseless = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale1_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin2_sc1_noisy = MCSamples(
    samples=samples_bin2_sc1_noisy,
    names=labels,
    label="Noisy, bin2, scale1",
)
samples_bin2_sc1_noiseless = MCSamples(
    samples=samples_bin2_sc1_noiseless,
    names=labels,
    label="Noiseless, bin2, scale1",
)
samples_bin2_sc1_noisy044 = MCSamples(
    samples=samples_bin2_sc1_noisy044,
    names=labels,
    label="Noisy044, bin2, scale1",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin2_sc1_noisy044, samples_bin2_sc1_noisy, samples_bin2_sc1_noiseless],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale2

# %%
samples_bin2_sc2_noisy = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale2_noisy_s0.26_npe.npy')
samples_bin2_sc2_noisy044 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale2_noisy_s0.44_npe.npy')
samples_bin2_sc2_noiseless = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale2_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin2_sc2_noisy = MCSamples(
    samples=samples_bin2_sc2_noisy,
    names=labels,
    label="Noisy, bin2, scale2",
)
samples_bin2_sc2_noiseless = MCSamples(
    samples=samples_bin2_sc2_noiseless,
    names=labels,
    label="Noiseless, bin2, scale2",
)
samples_bin2_sc2_noisy044 = MCSamples(
    samples=samples_bin2_sc2_noisy044,
    names=labels,
    label="Noisy044, bin2, scale2",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin2_sc2_noisy044, samples_bin2_sc2_noisy, samples_bin2_sc2_noiseless],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Auto & Cross power spectra

# %%
cross_ps_lmax_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
# cross_ps_lmax_400 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-400_r20_noisy_s0.26_npe.npy')

# %%
cross_ps_bar_lmax_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
cross_ps_bar_lmax_400 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-400_r20_noisy_s0.26_npe.npy')
auto_ps_bar_lmax_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_baryonified_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')
auto_ps_bar_lmax_400 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_baryonified_bins1234_l30-400_r20_noisy_s0.26_npe.npy')

cross_ps_bar_BNT_lmax_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

cross_ps_lmax_1024 = MCSamples(
    samples=cross_ps_lmax_1024,
    names=labels,
    label="A&C PS, NoBar, lmax=1024"
)
# cross_ps_lmax_400 = MCSamples(
#     samples=cross_ps_lmax_400,
#     names=labels,
#     label="A&C PS, NoBar, lmax=400",
# )

cross_ps_bar_lmax_1024 = MCSamples(
    samples=cross_ps_bar_lmax_1024,
    names=labels,
    label="A&C PS, Bar, lmax=1024"
)
cross_ps_bar_lmax_400 = MCSamples(
    samples=cross_ps_bar_lmax_400,
    names=labels,
    label="A&C PS, Bar, lmax=400",
)

auto_ps_bar_lmax_1024 = MCSamples(
    samples=auto_ps_bar_lmax_1024,
    names=labels,
    label="A PS, Bar, lmax=1024"
)
auto_ps_bar_lmax_400 = MCSamples(
    samples=auto_ps_bar_lmax_400,
    names=labels,
    label="A PS, Bar, lmax=400",
)

cross_ps_bar_BNT_lmax_1024 = MCSamples(
    samples=cross_ps_bar_BNT_lmax_1024,
    names=labels,
    label="A&C PS, Bar, lmax=1024, BNT",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([auto_ps_bar_lmax_400, cross_ps_bar_lmax_400, auto_ps_bar_lmax_1024, cross_ps_bar_lmax_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([cross_ps_bar_BNT_lmax_1024, auto_ps_bar_lmax_400, cross_ps_bar_lmax_400],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([cross_ps_lmax_1024, cross_ps_bar_lmax_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([cross_ps_bar_lmax_400, cross_ps_lmax_1024, cross_ps_bar_lmax_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()
g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

line_arguments = [
    {'color': 'blue','lw': 1.3},                  # for cross_ps_lmax_600
    {'color': 'red','lw': 1.3},                  # for cross_ps_bar_lmax_600
    {'color': 'blue', 'ls': '--', 'lw': 0.5},        # for cross_ps_lmax_1024 (dashed)
    {'color': 'red', 'ls': '--', 'lw': 0.5}         # for cross_ps_bar_lmax_1024 (dashed)
]

# Plot 600 lmax curves with filled contours
g.triangle_plot([cross_ps_lmax_600, cross_ps_bar_lmax_600, cross_ps_lmax_1024, cross_ps_bar_lmax_1024],
                filled=[True, True, False, False],  # filled for the first two, not filled for the last two
                markers={label: val for label, val in zip(labels, true_params[0])},
                colors=['blue', 'red', 'blue', 'red'],
                # contour_lws=1.1,
                line_args=line_arguments,
                marker_args={'color': 'black', 'lw': 1.},
                )
