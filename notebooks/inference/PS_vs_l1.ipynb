# %% [markdown]
# # Power Spectrum vs $\ell_1$-norm contours

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
# %matplotlib inline

# %% [markdown]
# ## Bin1

# %%
samples_bin1_PS = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bin1_l30-1024_r10_noisy_s0.26_npe.npy')
# samples_bin1_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scale2_noisy_s0.26_npe.npy')
samples_bin1_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scales1234_noisy_s0.26_new_normalization_npe.npy')
samples_bin1_peaks = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin1_scales1234_noisy_s0.26_new_normalization_npe.npy')
samples_bin1_3sc_peaks = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin1_scales123_noisy_s0.26_new_normalization_npe.npy')
samples_bin2_peaks = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin2_scales1234_noisy_s0.26_new_normalization_npe.npy')
samples_bin2_3sc_peaks = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin2_scales123_noisy_s0.26_new_normalization_npe.npy')
samples_bin3_peaks = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin3_scales123_noisy_s0.26_new_normalization_npe.npy')
samples_bin4_peaks = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin4_scales123_noisy_s0.26_new_normalization_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_PS = MCSamples(
    samples=samples_bin1_PS,
    names=labels,
    label="PS",
)
samples_bin1_l1 = MCSamples(
    samples=samples_bin1_l1,
    names=labels,
    label="L1",
)
samples_bin1_peaks = MCSamples(
    samples=samples_bin1_peaks,
    names=labels,
    label="Peaks",
)
samples_bin2_peaks = MCSamples(
    samples=samples_bin2_peaks,
    names=labels,
    label="Peaks bin2",
)
samples_bin3_peaks = MCSamples(
    samples=samples_bin3_peaks,
    names=labels,
    label="Peaks bin3",
)
samples_bin4_peaks = MCSamples(
    samples=samples_bin4_peaks,
    names=labels,
    label="Peaks bin4",
)
samples_bin1_3sc_peaks = MCSamples(
    samples=samples_bin1_3sc_peaks,
    names=labels,
    label="Peaks bin1 3sc",
)
samples_bin2_3sc_peaks = MCSamples(
    samples=samples_bin2_3sc_peaks,
    names=labels,
    label="Peaks bin2 3sc",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 1

g.triangle_plot([samples_bin1_PS, samples_bin1_peaks, samples_bin1_l1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                colors=['blue', 'red', 'green'],
                line_args=[
                    {'color': 'blue', 'lw': 1.5},     # PS outline
                    {'color': 'red', 'lw': 1.5},  # peaks outline
                    {'color': 'green', 'lw': 1.5}    # new_l1 outline
                ],
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_PS, samples_bin1_peaks, samples_bin2_peaks, samples_bin1_l1, samples_bin3_peaks, samples_bin4_peaks],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([ samples_bin1_peaks, samples_bin1_3sc_peaks],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomographic

# %%
samples_bin1_PS = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')
samples_bin1_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12345_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_PS = MCSamples(
    samples=samples_bin1_PS,
    names=labels,
    label="PS",
)
samples_bin1_l1 = MCSamples(
    samples=samples_bin1_l1,
    names=labels,
    label="L1",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_l1, samples_bin1_PS],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomographic PS, bar vs no-bar

# %%
samples_PS_nobar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')
samples_PS_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_baryonified_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_PS_nobar = MCSamples(
    samples=samples_PS_nobar,
    names=labels,
    label="PS no-bar"
)
samples_PS_bar = MCSamples(
    samples=samples_PS_bar,
    names=labels,
    label="PS bar"
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_PS_nobar, samples_PS_bar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomographic l1 vs One-bin l1

# %%
samples_bin3_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scales12345_noisy_s0.26_npe.npy')
samples_l1_tomo = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12345_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin3_l1 = MCSamples(
    samples=samples_bin3_l1,
    names=labels,
    label="Bin 3 l1",
)
samples_l1_tomo = MCSamples(
    samples=samples_l1_tomo,
    names=labels,
    label="Tomo l1",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_l1, samples_l1_tomo],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomographic PS vs One-bin PS

# %%
samples_bin3_PS = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bin2_l30-1024_r10_noisy_s0.26_npe.npy')
samples_PS_tomo = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin3_PS = MCSamples(
    samples=samples_bin3_PS,
    names=labels,
    label="Bin 3 PS",
)
samples_PS_tomo = MCSamples(
    samples=samples_PS_tomo,
    names=labels,
    label="Tomo PS",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_PS, samples_PS_tomo],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Old l1 vs New l1

# %%
samples_bin3_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scale1_noisy_s0.26_npe.npy')
samples_bin3_l1_new = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scale1_noisy_s0.26_new_normalization_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin3_l1 = MCSamples(
    samples=samples_bin3_l1,
    names=labels,
    label="Bin 3 l1",
)
samples_bin3_l1_new = MCSamples(
    samples=samples_bin3_l1_new,
    names=labels,
    label="Bin 3 l1 New",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_l1, samples_bin3_l1_new],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Old l1 vs New l1 Multiscale

# %%
samples_bin3_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scales12345_noisy_s0.26_npe.npy')
samples_bin3_l1_new = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scales1234_noisy_s0.26_new_normalization_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin3_l1 = MCSamples(
    samples=samples_bin3_l1,
    names=labels,
    label="Bin 3 l1",
)
samples_bin3_l1_new = MCSamples(
    samples=samples_bin3_l1_new,
    names=labels,
    label="Bin 3 l1 New",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_l1, samples_bin3_l1_new],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Compare new l1 multisacale contours for different bins

# %%
samples_bin1_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scales1234_noisy_s0.26_new_normalization_npe.npy')
samples_bin2_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scales1234_noisy_s0.26_new_normalization_npe.npy')
samples_bin3_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scales1234_noisy_s0.26_new_normalization_npe.npy')
samples_bin4_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin4_scales123_noisy_s0.26_new_normalization_npe.npy')  

samples_bins1234_sc01_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12_noisy_s0.26_new_normalization_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_l1 = MCSamples(
    samples=samples_bin1_l1,
    names=labels,
    label="Bin 1 l1",
)
samples_bin2_l1 = MCSamples(
    samples=samples_bin2_l1,
    names=labels,
    label="Bin 2 l1",
)
samples_bin3_l1 = MCSamples(
    samples=samples_bin3_l1,
    names=labels,
    label="Bin 3 l1",
)
samples_bin4_l1 = MCSamples(
    samples=samples_bin4_l1,
    names=labels,
    label="Bin 4 l1",
)


samples_bins1234_sc01_l1 = MCSamples(
    samples=samples_bins1234_sc01_l1,
    names=labels,
    label="Bins 1-4 l1",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_l1, samples_bin2_l1, samples_bin3_l1, samples_bin4_l1, samples_bins1234_sc01_l1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomographic new l1 vs PS

# %%
samples_PS = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')
samples_PS_auto_cross = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_new_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales123_noisy_s0.26_new_normalization_npe.npy')
samples_peaks = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bins1234_scales123_noisy_s0.26_new_normalization_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_PS = MCSamples(
    samples=samples_PS,
    names=labels,
    label="PS",
)
samples_PS_auto_cross = MCSamples(
    samples=samples_PS_auto_cross,
    names=labels,
    label="PS auto+cross",
)
samples_new_l1 = MCSamples(
    samples=samples_new_l1,
    names=labels,
    label="L1",
)
samples_peaks = MCSamples(
    samples=samples_peaks,
    names=labels,
    label="Peaks",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 1

g.triangle_plot([samples_PS, samples_PS_auto_cross, samples_peaks, samples_new_l1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                colors=['blue', 'orange', 'red', 'green'],
                line_args=[
                    {'color': 'blue', 'lw': 1.5},     # PS outline
                    {'color': 'orange', 'lw': 1.5},  # PS auto+cross outline
                    {'color': 'red', 'lw': 1.5},  # peaks outline
                    {'color': 'green', 'lw': 1.5}    # new_l1 outline
                ],
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 1

g.triangle_plot([samples_PS_auto_cross, samples_PS],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                colors=['blue', 'red'],
                line_args=[
                    {'color': 'blue', 'lw': 1.5},     # PS outline
                    {'color': 'red', 'lw': 1.5},  # peaks outline
                ],
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1, samples_new_l1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_l1, samples_new_l1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Old l1 vs new l1 (multiscale & tomographic)

# %%
samples_old_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12345_noisy_s0.26_npe.npy')
samples_new_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales123_noisy_s0.26_new_normalization_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_old_l1 = MCSamples(
    samples=samples_old_l1,
    names=labels,
    label="Old L1",
)
samples_new_l1 = MCSamples(
    samples=samples_new_l1,
    names=labels,
    label="New L1",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_old_l1, samples_new_l1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # CNN vs PS vs l1

# %%
samples_bin1_PS = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bin1_l30-1024_r10_noisy_s0.26_npe.npy')
samples_CNN_gal_density10 = np.load('/home/tersenov/software/Learn2Map/scripts/sbi/samples/posterior_samples_nbody_vmim_nle.npy')
samples_CNN_gal_density30 = np.load('/home/tersenov/software/cnn_sbi/scripts/sbi/samples/posterior_vmim_nbody_gal_density30.npy')
samples_CNN_overfit = np.load('/home/tersenov/software/cnn_sbi/notebooks/sbi/posterior_vmim_nbody_gal_density30_overfit_compressor_model.npy')
samples_bin1_l1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scales12345_noisy_s0.26_npe.npy')

# %%
samples_CNN_gal_density10[:, 3] *= 100
samples_CNN_gal_density30[:, 3] *= 100
samples_CNN_overfit[:, 3] *= 100

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_PS = MCSamples(
    samples=samples_bin1_PS,
    names=labels,
    label="PS",
)
samples_bin1_l1 = MCSamples(
    samples=samples_bin1_l1,
    names=labels,
    label="L1",
)

samples_CNN_gal_density10 = MCSamples(
    samples=samples_CNN_gal_density10,
    names=labels,
    label="CNN",
)

samples_CNN_gal_density30 = MCSamples(
    samples=samples_CNN_gal_density30,
    names=labels,
    label="CNN gal density 30",
)

samples_CNN_overfit = MCSamples(
    samples=samples_CNN_overfit,
    names=labels,
    label="CNN overfit",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_CNN_overfit, samples_bin1_PS, samples_bin1_l1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomographic CNN vs one-bin CNN

# %%
samples_CNN_tomo = np.load('/home/tersenov/software/cnn_sbi/notebooks/sbi/posterior_vmim_nbody_gal_density30_tomographic.npy')
samples_CNN_bin4 = np.load('/home/tersenov/software/cnn_sbi/scripts/sbi/samples/posterior_vmim_nbody_gal_density30.npy')
samples_CNN_bin4_NPE = np.load('/home/tersenov/software/cnn_sbi/notebooks/sbi/posterior_vmim_nbody_gal_density10_bin4_NPE.npy')
samples_CNN_tomo_BNT_NPE = np.load('/home/tersenov/software/cnn_sbi/notebooks/sbi/posterior_vmim_nbody_gal_density30_tomographic_BNT_NPE.npy')
samples_CNN_tomo_BNT = np.load('/home/tersenov/software/cnn_sbi/notebooks/sbi/posterior_vmim_nbody_gal_density30_tomographic_BNT.npy')

# %%
samples_CNN_tomo[:, 3] *= 100
samples_CNN_bin4[:, 3] *= 100
samples_CNN_bin4_NPE[:, 3] *= 100
samples_CNN_tomo_BNT_NPE[:, 3] *= 100
samples_CNN_tomo_BNT[:, 3] *= 100

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_CNN_tomo = MCSamples(
    samples=samples_CNN_tomo,
    names=labels,
    label="CNN tomo",
)

samples_CNN_bin4 = MCSamples(
    samples=samples_CNN_bin4,
    names=labels,
    label="CNN bin4",
)

samples_CNN_bin4_NPE = MCSamples(
    samples=samples_CNN_bin4_NPE,
    names=labels,
    label="CNN bin4 NPE",
)

samples_CNN_tomo_BNT_NPE = MCSamples(
    samples=samples_CNN_tomo_BNT_NPE,
    names=labels,
    label="CNN tomo BNT NPE",
)

samples_CNN_tomo_BNT = MCSamples(
    samples=samples_CNN_tomo_BNT,
    names=labels,
    label="CNN tomo BNT",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_CNN_bin4, samples_CNN_bin4_NPE, samples_CNN_tomo],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_CNN_bin4_NPE, samples_bin1_PS],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_CNN_tomo_BNT, samples_CNN_tomo],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomographic CNN vs PS vs l1

# %%
samples_CNN_tomo = np.load('/home/tersenov/software/cnn_sbi/notebooks/sbi/posterior_vmim_nbody_gal_density30_tomographic.npy')
samples_PS_tomo = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')
samples_l1_tomo = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales123_noisy_s0.26_new_normalization_npe.npy')

# %%
samples_CNN_tomo[:, 3] *= 100

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_PS_tomo = MCSamples(
    samples=samples_PS_tomo,
    names=labels,
    label="PS",
)
samples_l1_tomo = MCSamples(
    samples=samples_l1_tomo,
    names=labels,
    label="L1",
)

samples_CNN_tomo = MCSamples(
    samples=samples_CNN_tomo,
    names=labels,
    label="CNN",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_CNN_tomo, samples_PS_tomo, samples_l1_tomo],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()
