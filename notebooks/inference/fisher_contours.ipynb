# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
# %matplotlib inline

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]
labels_subset = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$"]

# Subset indices from the original labels
subset_indices = [0, 1, 2]  # indices of the first 3 parameters in your labels list

def subset_mcsamples(mcsamples, indices):
    # Extract subset of samples corresponding to the desired parameters
    # samples array shape: (num_samples, num_params)
    subset_samples = mcsamples.samples[:, indices]
    subset_labels = [labels[i] for i in indices]
    # Recreate MCSamples object with subsets
    return MCSamples(samples=subset_samples, names=subset_labels, label=mcsamples.label)

# Also subset true_params for markers accordingly
true_params_subset = true_params[0, subset_indices]

# %% [markdown]
# ### Auto & cross

# %%
PS_full = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bins1234_l30-1024_r20_auto_cross_noisy_s0.26_gaussian_samples.npy')
PS_full_131424 = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bins1234_l30-1024_r20_auto_cross_1-3_1-4_2-4_noisy_s0.26_gaussian_samples.npy')
PS_full_bnt = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bnt_bins1234_l30-1024_r20_auto_cross_noisy_s0.26_gaussian_samples.npy')
PS_full_bnt_131424 = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bnt_bins1234_l30-1024_r20_auto_cross_1-3_1-4_2-4_noisy_s0.26_gaussian_samples.npy')
PS_full_bnt_13 = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bnt_bins1234_l30-1024_r20_auto_cross_1-3_noisy_s0.26_gaussian_samples.npy')

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

PS_full = MCSamples(    
    samples=PS_full,
    names=labels,
    label="PS_full"
)

PS_full_131424 = MCSamples(
    samples=PS_full_131424,
    names=labels,
    label="PS_full_131424"
)

PS_full_bnt = MCSamples(
    samples=PS_full_bnt,
    names=labels,
    label="PS_full_bnt"
)

PS_full_bnt_131424 = MCSamples(
    samples=PS_full_bnt_131424,
    names=labels,
    label="PS_full_bnt_131424"
)
PS_full_bnt_13 = MCSamples(
    samples=PS_full_bnt_13,
    names=labels,
    label="PS_full_bnt_13"
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_full_bnt_131424, PS_full_131424],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Auto

# %%
PS_auto_bnt = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bntbins1234_l30-1024_r20_noisy_s0.26_gaussian_samples.npy')
PS_auto = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_gaussian_samples.npy')

# %%
PS_auto_SBI = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

PS_auto = MCSamples(    
    samples=PS_auto,
    names=labels,
    label="PS_auto"
)
PS_auto_bnt = MCSamples(
    samples=PS_auto_bnt,
    names=labels,
    label="PS_auto_bnt"
)

PS_auto_SBI = MCSamples(
    samples=PS_auto_SBI,
    names=labels,
    label="PS_auto_SBI"
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_bnt, PS_auto],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Cross only

# %%
PS_cross = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bins1234_l30-1024_r20_cross_noisy_s0.26_gaussian_samples.npy')
PS_cross_bnt = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bnt_bins1234_l30-1024_r20_cross_noisy_s0.26_gaussian_samples.npy')

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

PS_cross = MCSamples(    
    samples=PS_cross,
    names=labels,
    label="PS_cross"
)
PS_cross_bnt = MCSamples(
    samples=PS_cross_bnt,
    names=labels,
    label="PS_cross_bnt"
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_cross_bnt, PS_cross, PS_full_131424],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Auto vs full

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto, PS_full_131424],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_full_bnt_13, PS_auto_bnt, PS_full_bnt_131424],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Bin 1 (old vs new)

# %%
PS_bin1_old = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bin1_l30-1024_r20_noisy_s0.26_gaussian_samples.npy')
PS_bin1_new = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bin1_l30-1024_r20_noisy_s0.26_gaussian_samples_new.npy')

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

PS_bin1_old = MCSamples(    
    samples=PS_bin1_old,
    names=labels,
    label="PS_bin1_old"
)
PS_bin1_new = MCSamples(
    samples=PS_bin1_new,
    names=labels,
    label="PS_bin1_new"
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_bin1_new, PS_bin1_old],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Very noisy

# %%
PS_auto_very_noisy = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bins1234_l30-1024_r20_noisy_s0.50_gaussian_samples.npy')
PS_auto_cross_very_noisy = np.load('/home/tersenov/software/bar_impact/outputs/fisher/fisher_ps_nobaryons_vs_nobaryons_nobaryons_bins1234_l30-1024_r20_auto_cross_noisy_s0.50_gaussian_samples.npy')

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

PS_auto_very_noisy = MCSamples(    
    samples=PS_auto_very_noisy,
    names=labels,
    label="PS_auto_very_noisy"
)
PS_auto_cross_very_noisy = MCSamples(
    samples=PS_auto_cross_very_noisy,
    names=labels,
    label="PS_auto_cross_very_noisy"
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_very_noisy, PS_auto_cross_very_noisy],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()
