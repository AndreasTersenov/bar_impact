# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
# %matplotlib inline

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]
labels_subset = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$"]

# Subset indices from the original labels
subset_indices = [0, 1, 2]  # indices of the first 3 parameters in your labels list

def subset_mcsamples(mcsamples, indices):
    # Extract subset of samples corresponding to the desired parameters
    # samples array shape: (num_samples, num_params)
    subset_samples = mcsamples.samples[:, indices]
    subset_labels = [labels[i] for i in indices]
    # Recreate MCSamples object with subsets
    return MCSamples(samples=subset_samples, names=subset_labels, label=mcsamples.label)

# Also subset true_params for markers accordingly
true_params_subset = true_params[0, subset_indices]

# %%
PS_auto_noisy = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')
l1_noisy = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales123_noisy_s0.26_new_normalization_npe.npy')

PS_auto_noiseless = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_npe.npy')
PS_auto_cross_noiseless = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_npe.npy')
PS_cross_noiseless = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_npe.npy')
ps_test = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_1-2_1-3_1-4_2-3_2-4_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_npe.npy')
PS_auto_cross_noiseless_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r50_npe.npy')


PS_auto_noiseless_BNT = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bntbins1234_l30-1024_r20_npe.npy')
PS_auto_cross_noiseless_BNT = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_npe.npy')
PS_auto_cross_noiseless_BNT_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r50_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]
# labels = ["Om", "s8", "w0", "H0", "ns", "Ob"]

PS_auto_noisy = MCSamples(
    samples=PS_auto_noisy,
    names=labels,
    label="PS auto, noisy"
)
PS_auto_noiseless = MCSamples(
    samples=PS_auto_noiseless,
    names=labels,
    label="PS auto, noiseless"
)
PS_auto_cross_noiseless = MCSamples(
    samples=PS_auto_cross_noiseless,
    names=labels,
    label="PS auto&cross, noiseless"
)
PS_cross_noiseless = MCSamples(
    samples=PS_cross_noiseless,
    names=labels,
    label="PS cross, noiseless"
)
PS_auto_cross_noiseless_2048 = MCSamples(
    samples=PS_auto_cross_noiseless_2048,
    names=labels,
    label="PS auto&cross 2048, noiseless"
)

PS_auto_cross_noiseless_BNT = MCSamples(
    samples=PS_auto_cross_noiseless_BNT,
    names=labels,
    label="PS auto&cross, noiseless, BNT"
)
PS_auto_cross_noiseless_BNT_2048 = MCSamples(
    samples=PS_auto_cross_noiseless_BNT_2048,
    names=labels,
    label="PS auto&cross 2048, noiseless, BNT"
)
PS_auto_noiseless_BNT = MCSamples(
    samples=PS_auto_noiseless_BNT,
    names=labels,
    label="PS auto, noiseless, BNT"
)
ps_test = MCSamples(
    samples=ps_test,
    names=labels,
    label="PS auto&cross 1-2,1-3,1-4,2-3,2-4, noiseless"
)

l1_noisy = MCSamples(
    samples=l1_noisy,
    names=labels,
    label="L1, noisy"
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_cross_noiseless, PS_auto_noiseless, PS_auto_cross_noiseless, PS_auto_cross_noiseless_2048],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_noiseless_BNT, PS_auto_cross_noiseless_BNT, PS_auto_cross_noiseless_BNT_2048],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_noiseless_2048, PS_auto_cross_noiseless_BNT_2048],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Large noise

# %%
PS_auto_very_noisy = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_nobaryons_vs_nobaryons_bins1234_l30-1024_r50_noisy_s0.51_npe.npy')
PS_auto_cross_very_noisy = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r70_noisy_s0.51_npe.npy')
PS_cross_very_noisy = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r50_noisy_s0.51_npe.npy')

# %%
PS_auto_very_noisy = MCSamples(
    samples=PS_auto_very_noisy,
    names=labels,
    label="PS auto, very noisy"
)
PS_auto_cross_very_noisy = MCSamples(
    samples=PS_auto_cross_very_noisy,
    names=labels,
    label="PS auto&cross, very noisy"
)
PS_cross_very_noisy = MCSamples(
    samples=PS_cross_very_noisy,
    names=labels,
    label="PS cross, very noisy"
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_very_noisy, PS_cross_very_noisy, PS_auto_cross_very_noisy],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_very_noisy, PS_auto_cross_noiseless],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Normal noise

# %%
PS_auto_noisy_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_nobaryons_vs_nobaryons_bins1234_l30-2048_r100_noisy_s0.26_npe.npy')
PS_auto_cross_noisy_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r100_noisy_s0.26_npe.npy')
PS_cross_noisy_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r100_noisy_s0.26_npe.npy')
PS_auto_noisy_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')
PS_auto_cross_noisy_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')
PS_cross_noisy_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')


PS_BNT_auto_cross_noisy_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r100_noisy_s0.26_npe.npy')
PS_BNT_auto_cross_noisy_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')

# %%
PS_auto_cross_noisy_2048 = MCSamples(
    samples=PS_auto_cross_noisy_2048,
    names=labels,
    label="PS auto&cross, noisy, 2048"
)
PS_auto_noisy_2048 = MCSamples(
    samples=PS_auto_noisy_2048,
    names=labels,
    label="PS auto, noisy, 2048"
)
PS_cross_noisy_2048 = MCSamples(
    samples=PS_cross_noisy_2048,
    names=labels,
    label="PS cross, noisy, 2048"
)
PS_auto_cross_noisy_1024 = MCSamples(
    samples=PS_auto_cross_noisy_1024,
    names=labels,
    label="PS auto&cross, noisy, 1024"
)
PS_auto_noisy_1024 = MCSamples(
    samples=PS_auto_noisy_1024,
    names=labels,
    label="PS auto, noisy, 1024"
)   
PS_cross_noisy_1024 = MCSamples(
    samples=PS_cross_noisy_1024,
    names=labels,
    label="PS cross, noisy, 1024"
)


PS_BNT_auto_cross_noisy_2048 = MCSamples(
    samples=PS_BNT_auto_cross_noisy_2048,
    names=labels,
    label="BNT PS auto&cross, noisy, 2048"
)
PS_BNT_auto_cross_noisy_1024 = MCSamples(
    samples=PS_BNT_auto_cross_noisy_1024,
    names=labels,
    label="BNT PS auto&cross, noisy, 1024"
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# #### BNT vs noBNT

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_BNT_auto_cross_noisy_2048, PS_auto_cross_noisy_2048],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_BNT_auto_cross_noisy_1024, PS_auto_cross_noisy_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### Auto vs Cross

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_noisy_2048, PS_cross_noisy_2048, PS_auto_cross_noisy_2048],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_noisy_1024, PS_cross_noisy_1024, PS_auto_cross_noisy_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### 2048 vs 1024

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_noisy_2048, PS_auto_cross_noisy_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Masked vs unmasked

# %%
PS_auto_cross_masked_bar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_bar_800 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-800_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
# PS_auto_cross_masked_nobar_800 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-800_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_bar_700 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-700_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_nobar_700 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-700_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_bar_600 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-600_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_nobar_600 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-600_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')


# PS_BNT_auto_cross_noisy_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r100_noisy_s0.26_npe.npy')
# PS_BNT_auto_cross_noisy_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')

# %%
PS_auto_cross_masked_bar_1024 = MCSamples(
    samples=PS_auto_cross_masked_bar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 1024"
)
PS_auto_cross_masked_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked, no bar, 1024"
)
PS_auto_cross_masked_bar_800 = MCSamples(
    samples=PS_auto_cross_masked_bar_800,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 800"
)
# PS_auto_cross_masked_nobar_800 = MCSamples(
#     samples=PS_auto_cross_masked_nobar_800,
#     names=labels,
#     label="PS auto&cross, noisy, masked, no bar, 800"
# )
PS_auto_cross_masked_bar_700 = MCSamples(
    samples=PS_auto_cross_masked_bar_700,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 700"
)
PS_auto_cross_masked_nobar_700 = MCSamples(
    samples=PS_auto_cross_masked_nobar_700,
    names=labels,
    label="PS auto&cross, noisy, masked, no bar, 700"
)
PS_auto_cross_masked_bar_600 = MCSamples(
    samples=PS_auto_cross_masked_bar_600,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 600"
)
PS_auto_cross_masked_nobar_600 = MCSamples(
    samples=PS_auto_cross_masked_nobar_600,
    names=labels,
    label="PS auto&cross, noisy, masked, no bar, 600"
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# #### Bar vs noBar

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked_nobar_1024, PS_auto_cross_masked_bar_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked_nobar_700, PS_auto_cross_masked_bar_700],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked_nobar_600, PS_auto_cross_masked_bar_600],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()
