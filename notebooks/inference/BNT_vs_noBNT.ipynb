# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
# %matplotlib inline

# %% [markdown]
# # l1-norm

# %% [markdown]
# ### Bin1

# %% [markdown]
# #### Bin 1, scale 1

# %%
samples_bin1_sc1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt1_scale1_noisy_s0.26_npe.npy')
samples_bin1_sc1_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc1_bnt = MCSamples(
    samples=samples_bin1_sc1_bnt,
    names=labels,
    label="NoBar, bin1, scale1, BNT",
)
samples_bin1_sc1_nobnt = MCSamples(
    samples=samples_bin1_sc1_nobnt,
    names=labels,
    label="NoBar, bin1, scale1, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc1_bnt, samples_bin1_sc1_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### Bin 1, scale 2

# %%
samples_bin1_sc2_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt1_scale2_noisy_s0.26_npe.npy')
samples_bin1_sc2_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1_sc2_bnt = MCSamples(
    samples=samples_bin1_sc2_bnt,
    names=labels,
    label="NoBar, bin1, scale2, BNT",
)
samples_bin1_sc2_nobnt = MCSamples(
    samples=samples_bin1_sc2_nobnt,
    names=labels,
    label="NoBar, bin1, scale2, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1_sc2_bnt, samples_bin1_sc2_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Bin2

# %% [markdown]
# #### Bin 2, scale 1

# %%
samples_bin2_sc1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt2_scale1_noisy_s0.26_npe.npy')
samples_bin2_sc1_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin2_sc1_bnt = MCSamples(
    samples=samples_bin2_sc1_bnt,
    names=labels,
    label="NoBar, bin2, scale1, BNT",
)
samples_bin2_sc1_nobnt = MCSamples(
    samples=samples_bin2_sc1_nobnt,
    names=labels,
    label="NoBar, bin2, scale1, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin2_sc1_bnt, samples_bin2_sc1_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### Bin 2, scale 2

# %%
samples_bin2_sc2_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt2_scale2_noisy_s0.26_npe.npy')
samples_bin2_sc2_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin2_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin2_sc2_bnt = MCSamples(
    samples=samples_bin2_sc2_bnt,
    names=labels,
    label="NoBar, bin2, scale2, BNT",
)
samples_bin2_sc2_nobnt = MCSamples(
    samples=samples_bin2_sc2_nobnt,
    names=labels,
    label="NoBar, bin2, scale2, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin2_sc2_bnt, samples_bin2_sc2_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Bin3

# %% [markdown]
# #### Bin 3, scale 1

# %%
samples_bin3_sc1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt3_scale1_noisy_s0.26_npe.npy')
samples_bin3_sc1_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin3_sc1_bnt = MCSamples(
    samples=samples_bin3_sc1_bnt,
    names=labels,
    label="NoBar, bin3, scale1, BNT",
)
samples_bin3_sc1_nobnt = MCSamples(
    samples=samples_bin3_sc1_nobnt,
    names=labels,
    label="NoBar, bin3, scale1, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_sc1_bnt, samples_bin3_sc1_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### Bin 3, scale 2

# %%
samples_bin3_sc2_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt3_scale2_noisy_s0.26_npe.npy')
samples_bin3_sc2_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin3_sc2_bnt = MCSamples(
    samples=samples_bin3_sc2_bnt,
    names=labels,
    label="NoBar, bin3, scale2, BNT",
)
samples_bin3_sc2_nobnt = MCSamples(
    samples=samples_bin3_sc2_nobnt,
    names=labels,
    label="NoBar, bin3, scale2, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_sc2_bnt, samples_bin3_sc2_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Bin4

# %% [markdown]
# #### Bin 4, scale 1

# %%
samples_bin4_sc1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt4_scale1_noisy_s0.26_npe.npy')
samples_bin4_sc1_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin4_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin4_sc1_bnt = MCSamples(
    samples=samples_bin4_sc1_bnt,
    names=labels,
    label="NoBar, bin4, scale1, BNT",
)
samples_bin4_sc1_nobnt = MCSamples(
    samples=samples_bin4_sc1_nobnt,
    names=labels,
    label="NoBar, bin4, scale1, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin4_sc1_bnt, samples_bin4_sc1_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### Bin 4, scale 2

# %%
samples_bin4_sc2_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt4_scale2_noisy_s0.26_npe.npy')
samples_bin4_sc2_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin4_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin4_sc2_bnt = MCSamples(
    samples=samples_bin4_sc2_bnt,
    names=labels,
    label="NoBar, bin4, scale2, BNT",
)
samples_bin4_sc2_nobnt = MCSamples(
    samples=samples_bin4_sc2_nobnt,
    names=labels,
    label="NoBar, bin4, scale2, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin4_sc2_bnt, samples_bin4_sc2_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Different bins

# %% [markdown]
# #### Scale 1

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin4_sc1_bnt, samples_bin3_sc1_bnt, samples_bin2_sc1_bnt, samples_bin1_sc1_bnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### Scale 2

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin4_sc2_bnt, samples_bin3_sc2_bnt, samples_bin2_sc2_bnt, samples_bin1_sc2_bnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Multiscale

# %%
samples_bin3_sc12345_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt3_scales12345_noisy_s0.26_npe.npy')
samples_bin3_sc12345_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin3_scales12345_noisy_s0.26_npe.npy')


samples_bin3_sc12345_bnt = MCSamples(
    samples=samples_bin3_sc12345_bnt,
    names=labels,
    label="NoBar, bin3, scale1,2,3,4,5 BNT",
)

samples_bin3_sc12345_nobnt = MCSamples(
    samples=samples_bin3_sc12345_nobnt,
    names=labels,
    label="NoBar, bin3, scale1,2,3,4,5 noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_sc1_bnt, samples_bin3_sc12345_bnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_sc12345_bnt, samples_bin3_sc12345_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_sc1_nobnt, samples_bin3_sc12345_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomography

# %% [markdown]
# ### Scale 1

# %%
samples_bin1234_sc1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bntbins1234_scale1_noisy_s0.26_npe.npy')
samples_bin1234_sc1_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scale1_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1234_sc1_bnt = MCSamples(
    samples=samples_bin1234_sc1_bnt,
    names=labels,
    label="NoBar, bins1234, scale1, BNT",
)
samples_bin1234_sc1_nobnt = MCSamples(
    samples=samples_bin1234_sc1_nobnt,
    names=labels,
    label="NoBar, bins1234, scale1, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1234_sc1_bnt, samples_bin1234_sc1_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Scale 2

# %%
samples_bin1234_sc2_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bntbins1234_scale2_noisy_s0.26_npe.npy')
samples_bin1234_sc2_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scale2_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1234_sc2_bnt = MCSamples(
    samples=samples_bin1234_sc2_bnt,
    names=labels,
    label="NoBar, bins1234, scale2, BNT",
)
samples_bin1234_sc2_nobnt = MCSamples(
    samples=samples_bin1234_sc2_nobnt,
    names=labels,
    label="NoBar, bins1234, scale2, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1234_sc2_bnt, samples_bin1234_sc2_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Multiscale

# %%
samples_bin1234_sc12345_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bntbins1234_scales12345_noisy_s0.26_npe.npy')
samples_bin1234_sc12345_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12345_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_bin1234_sc12345_bnt = MCSamples(
    samples=samples_bin1234_sc12345_bnt,
    names=labels,
    label="NoBar, bins1234, all scales, BNT",
)
samples_bin1234_sc12345_nobnt = MCSamples(
    samples=samples_bin1234_sc12345_nobnt,
    names=labels,
    label="NoBar, bins1234, all scales, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin1234_sc12345_bnt, samples_bin1234_sc12345_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Tomo vs non-Tomo

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_sc12345_bnt, samples_bin1234_sc12345_bnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_bin3_sc12345_nobnt, samples_bin1234_sc12345_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # l1-norm (new normalization)

# %%
l1_bin1_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bin1_scales1234_noisy_s0.26_new_normalization_npe.npy')
l1_bin1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt1_scales1234_noisy_s0.26_new_normalization_npe.npy')
l1_bin1_bnt_binrange_17_23 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt1_scales1234_noisy_s0.26_new_normalization_binrange17-23_npe.npy')
l1_bin1_bnt_binrange_15_25 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt1_scales1234_noisy_s0.26_new_normalization_binrange15-25_npe.npy')
l1_bin1_bnt_binrange_19_21 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt1_scales1234_noisy_s0.26_new_normalization_binrange19-21_npe.npy')
l1_bin2_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt2_scales1234_noisy_s0.26_new_normalization_npe.npy')

l1_bin3_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt3_scales1234_noisy_s0.26_new_normalization_npe.npy')
l1_bin4_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bnt4_scales1234_noisy_s0.26_new_normalization_npe.npy')

l1_tomo_bnt_binrange_5_35 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bntbins1234_scales1234_noisy_s0.26_new_normalization_binrange5-35_npe.npy')
l1_tomo_bnt_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bntbins1234_scales1234_noisy_s0.26_new_normalization_binrange5-35_npe.npy')

l1_tomo_nobnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales123_noisy_s0.26_new_normalization_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]
 
l1_bin1_nobnt = MCSamples(
    samples=l1_bin1_nobnt,
    names=labels,
    label="L1, NoBar, bin1, noBNT",
)

l1_bin1_bnt = MCSamples(
    samples=l1_bin1_bnt,
    names=labels,
    label="L1, NoBar, bin1, BNT",
)

l1_bin1_bnt_binrange_17_23 = MCSamples(
    samples=l1_bin1_bnt_binrange_17_23,
    names=labels,
    label="L1, NoBar, bin1, binrange 17-23, BNT",
)

l1_bin1_bnt_binrange_15_25 = MCSamples(
    samples=l1_bin1_bnt_binrange_15_25,
    names=labels,
    label="L1, NoBar, bin1, binrange 15-25, BNT",
)

l1_bin1_bnt_binrange_19_21 = MCSamples(
    samples=l1_bin1_bnt_binrange_19_21,
    names=labels,
    label="L1, NoBar, bin1, binrange 19-21, BNT",
)

l1_bin2_bnt = MCSamples(
    samples=l1_bin2_bnt,
    names=labels,
    label="L1, NoBar, bin2, BNT",
)


l1_bin3_bnt = MCSamples(
    samples=l1_bin3_bnt,
    names=labels,
    label="L1, NoBar, bin3, BNT",
)
l1_bin4_bnt = MCSamples(
    samples=l1_bin4_bnt,
    names=labels,
    label="L1, NoBar, bin4, BNT",
)

l1_tomo_bnt_binrange_5_35 = MCSamples(
    samples=l1_tomo_bnt_binrange_5_35,
    names=labels,
    label="L1, NoBar, bins1234, binrange 5-35, BNT",
)

l1_tomo_bnt_bar = MCSamples(
    samples=l1_tomo_bnt_bar,
    names=labels,
    label="L1, Bar, bins1234, BNT",
)

l1_tomo_nobnt = MCSamples(
    samples=l1_tomo_nobnt,
    names=labels,
    label="L1, NoBar, bins1234, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([l1_bin4_bnt, l1_bin3_bnt, l1_bin2_bnt, l1_bin1_bnt, l1_tomo_bnt_binrange_5_35],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([l1_tomo_bnt_bar, l1_tomo_bnt_binrange_5_35, l1_tomo_nobnt],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Peak Counts

# %% [markdown]
# ### Bin 1

# %%
peaks_bin1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_pc_nobaryons_vs_nobaryons_bnt1_scales1234_noisy_s0.26_new_normalization_npe.npy')
peaks_bin1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin1_scales1234_noisy_s0.26_new_normalization_npe.npy')

labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

peaks_bin1_bnt = MCSamples(
    samples=peaks_bin1_bnt,
    names=labels,
    label="NoBar, bin1, BNT",
)

peaks_bin1 = MCSamples(
    samples=peaks_bin1,
    names=labels,
    label="NoBar, bin1, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([peaks_bin1_bnt, peaks_bin1],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Bin 2

# %%
peaks_bin2_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_pc_nobaryons_vs_nobaryons_bnt2_scales1234_noisy_s0.26_new_normalization_npe.npy')
peaks_bin2 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bin2_scales1234_noisy_s0.26_new_normalization_npe.npy')

labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

peaks_bin2_bnt = MCSamples(
    samples=peaks_bin2_bnt,
    names=labels,
    label="NoBar, bin2, BNT",
)

peaks_bin2 = MCSamples(
    samples=peaks_bin2,
    names=labels,
    label="NoBar, bin2, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([peaks_bin2_bnt, peaks_bin2],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Tomographic

# %%
peaks_bnt_tomo = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_pc_nobaryons_vs_nobaryons_bntbins1234_scales1234_noisy_s0.26_new_normalization_npe.npy')
peaks_bnt_tomo_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_pc_nobaryons_vs_baryonified_bntbins1234_scales1234_noisy_s0.26_new_normalization_npe.npy')
peaks_tomo = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_pc_nobaryons_vs_nobaryons_bins1234_scales123_noisy_s0.26_new_normalization_npe.npy')

labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

peaks_bnt_tomo = MCSamples(
    samples=peaks_bnt_tomo,
    names=labels,
    label="NoBar, tomo, BNT",
)

peaks_bnt_tomo_bar = MCSamples(
    samples=peaks_bnt_tomo_bar,
    names=labels,
    label="Bar, tomo, BNT",
)

peaks_tomo = MCSamples(
    samples=peaks_tomo,
    names=labels,
    label="NoBar, tomo, noBNT",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([peaks_bnt_tomo_bar, peaks_bnt_tomo, peaks_tomo],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Auto Power spectrum

# %% [markdown]
# #### Bin 1

# %%
samples_ps_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bnt1_l30-1024_r10_noisy_s0.26_npe.npy')
samples_ps = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bin1_l30-1024_r10_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_ps_bnt = MCSamples(
    samples=samples_ps_bnt,
    names=labels,
    label="PS BNT",
)

samples_ps = MCSamples(
    samples=samples_ps,
    names=labels,
    label="PS",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_ps_bnt_bar, samples_ps_bnt, samples_ps],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# #### Bin 4

# %%
samples_ps_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bnt4_l30-1024_r10_noisy_s0.26_npe.npy')
samples_ps = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bin2_l30-1024_r10_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_ps_bnt = MCSamples(
    samples=samples_ps_bnt,
    names=labels,
    label="PS BNT bin 4",
)

samples_ps = MCSamples(
    samples=samples_ps,
    names=labels,
    label="PS bin 2",
)
# Out:
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_ps_bnt, samples_ps],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Tomo

# %%
samples_ps_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bntbins1234_l30-1024_r10_noisy_s0.26_npe.npy')
samples_ps_bnt_r20 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bntbins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_ps_bnt_r50 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bntbins1234_l30-1024_r50_noisy_s0.26_npe.npy')
samples_ps_bnt1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bnt1_l30-1024_r10_noisy_s0.26_npe.npy')
samples_ps = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')
samples_ps_bnt_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_baryonified_bntbins1234_l30-1024_r20_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_ps_bnt = MCSamples(
    samples=samples_ps_bnt,
    names=labels,
    label="PS BNT tomo",
)

samples_ps_bnt_r20 = MCSamples(
    samples=samples_ps_bnt_r20,
    names=labels,
    label="PS BNT tomo r20",
)

samples_ps_bnt_r50 = MCSamples(
    samples=samples_ps_bnt_r50,
    names=labels,
    label="PS BNT tomo r50",
)

samples_ps_bnt1 = MCSamples(
    samples=samples_ps_bnt1,
    names=labels,
    label="PS BNT bin1",
)

samples_ps = MCSamples(
    samples=samples_ps,
    names=labels,
    label="PS tomo",
)

samples_ps_bnt_bar = MCSamples(
    samples=samples_ps_bnt_bar,
    names=labels,
    label="PS BNT, Bar",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_ps_bnt1, samples_ps_bnt, samples_ps_bnt_r20, samples_ps],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_ps_bnt_bar, samples_ps_bnt_r20, samples_ps],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # Auto&Cross Power spectrum

# %% [markdown]
# ### Tomo

# %%
samples_ps_bnt_cross = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_ps_cross = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_ps_cross_lmax600 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-600_r20_noisy_s0.26_npe.npy')
samples_ps_cross_lmax200 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-200_r20_noisy_s0.26_npe.npy')

samples_ps_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bntbins1234_l30-1024_r10_noisy_s0.26_npe.npy')
samples_ps_bnt_bar_cross13_14_24 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_1-3_1-4_2-4_nobaryons_vs_baryonified_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_ps_bnt_cross13_14_24 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_1-3_1-4_2-4_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_ps_bnt_cross14 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_1-4_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')

samples_ps_bnt_r20 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bntbins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_ps_bnt_r50 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bntbins1234_l30-1024_r50_noisy_s0.26_npe.npy')
samples_ps_bnt1 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bnt1_l30-1024_r10_noisy_s0.26_npe.npy')
samples_ps = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_nobaryons_vs_nobaryons_bins1234_l30-1024_r10_noisy_s0.26_npe.npy')

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_ps_bnt_cross = MCSamples(
    samples=samples_ps_bnt_cross,
    names=labels,
    label="PS BNT cross",
)

samples_ps_cross = MCSamples(
    samples=samples_ps_cross,
    names=labels,
    label="PS cross",
)

samples_ps_cross_lmax600 = MCSamples(
    samples=samples_ps_cross_lmax600,
    names=labels,
    label="PS cross lmax=600",
)

samples_ps_cross_lmax200 = MCSamples(
    samples=samples_ps_cross_lmax200,
    names=labels,
    label="PS cross lmax=200",
)

samples_ps_bnt = MCSamples(
    samples=samples_ps_bnt,
    names=labels,
    label="PS BNT tomo",
)

samples_ps_bnt_r20 = MCSamples(
    samples=samples_ps_bnt_r20,
    names=labels,
    label="PS BNT tomo r20",
)

samples_ps = MCSamples(
    samples=samples_ps,
    names=labels,
    label="PS tomo",
)

samples_ps_bnt_bar_cross13_14_24 = MCSamples(
    samples=samples_ps_bnt_bar_cross13_14_24,
    names=labels,
    label="PS cross tomo, bar, cross (1,3);(1,4);(2,4)",
)

samples_ps_bnt_cross13_14_24 = MCSamples(
    samples=samples_ps_bnt_cross13_14_24,
    names=labels,
    label="PS cross tomo, cross (1,3);(1,4);(2,4)",
)

samples_ps_bnt_cross14 = MCSamples(
    samples=samples_ps_bnt_cross14,
    names=labels,
    label="PS cross tomo, cross (1,4)",
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_ps_bnt_r20, samples_ps_bnt_cross, samples_ps_cross],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_ps_bnt, samples_ps_bnt_r20, samples_ps_bnt_r50, samples_ps],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_ps_cross_lmax200, samples_ps_cross_lmax600, samples_ps_cross],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # BNT PS vs BNT l1 vs BNT CNN

# %%
samples_ps_bnt_cross = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r20_noisy_s0.26_npe.npy')
samples_l1_bnt = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bntbins1234_scales12345_noisy_s0.26_npe.npy')
samples_CNN_bnt = np.load('/home/tersenov/software/cnn_sbi/notebooks/sbi/posterior_vmim_nbody_gal_density30_tomographic_BNT_NPE.npy')
samples_CNN_bnt[:, 3] *= 100

# %%
labels = [r"$\Omega_{m}$", r"$S_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]

samples_ps_bnt_cross = MCSamples(
    samples=samples_ps_bnt_cross,
    names=labels,
    label="PS BNT cross",
)

samples_l1_bnt = MCSamples(
    samples=samples_l1_bnt,
    names=labels,
    label="l1 BNT"
)

samples_CNN_bnt = MCSamples(
    samples=samples_CNN_bnt,
    names=labels,
    label="CNN BNT"
)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([samples_CNN_bnt, samples_l1_bnt, samples_ps_bnt_cross],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()
