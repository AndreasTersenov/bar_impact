# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
# %matplotlib inline

# %%
import scipy
import tensiometer
# from tensiometer.utilities import stats_utilities as utilities
import tensiometer.utilities as utilities
from tensiometer import mcmc_tension
from tensiometer import gaussian_tension

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

# %%
labels = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$", r"$H_0$", r"$n_s$", r"$\Omega_b$"]
labels_subset = [r"$\Omega_{m}$", r"$\sigma_8$", r"$w_0$"]

# Subset indices from the original labels
subset_indices = [0, 1, 2]  # indices of the first 3 parameters in your labels list

def subset_mcsamples(mcsamples, indices):
    # Extract subset of samples corresponding to the desired parameters
    # samples array shape: (num_samples, num_params)
    subset_samples = mcsamples.samples[:, indices]
    subset_labels = [labels[i] for i in indices]
    # Recreate MCSamples object with subsets
    return MCSamples(samples=subset_samples, names=subset_labels, label=mcsamples.label)

# Also subset true_params for markers accordingly
true_params_subset = true_params[0, subset_indices]

# %% [markdown]
# ## Masked

# %%
PS_auto_cross_masked5000_bar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_5000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked5000_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_5000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked28000_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_28000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked40000_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_40000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked40000_bar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_40000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked35000_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_35000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked35000_bar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_35000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked14000_bar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked14000_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked39000_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_39000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked39000_bar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_39000sqdeg_noisy_s0.26_npe.npy')

# %%
PS_auto_cross_masked5000_bar_1024 = MCSamples(
    samples=PS_auto_cross_masked5000_bar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 5000, bar, 1024"
)
PS_auto_cross_masked5000_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked5000_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 5000, no bar, 1024"
)
PS_auto_cross_masked28000_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked28000_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 28000, no bar, 1024"
)
PS_auto_cross_masked40000_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked40000_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 40000, no bar, 1024"
)
PS_auto_cross_masked35000_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked35000_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 35000, no bar, 1024"
)
PS_auto_cross_masked14000_bar_1024 = MCSamples(
    samples=PS_auto_cross_masked14000_bar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 14000, bar, 1024"
)
PS_auto_cross_masked14000_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked14000_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 14000, no bar, 1024"
)
PS_auto_cross_masked39000_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked39000_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 39000, no bar, 1024"
)
PS_auto_cross_masked35000_bar_1024 = MCSamples(
    samples=PS_auto_cross_masked35000_bar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 35000, bar, 1024",
)
PS_auto_cross_masked40000_bar_1024 = MCSamples(
    samples=PS_auto_cross_masked40000_bar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 40000, bar, 1024"
)
PS_auto_cross_masked39000_bar_1024 = MCSamples(
    samples=PS_auto_cross_masked39000_bar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked 39000, bar, 1024"
)

# %% [markdown]
# # Unmasked

# %%
PS_auto_cross_noisy_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r100_noisy_s0.26_npe.npy')
PS_auto_cross_noisy_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')
PS_auto_cross_noisy_1024_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')
PS_BNT_auto_cross_noisy_2048 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-2048_r100_noisy_s0.26_npe.npy')
PS_BNT_auto_cross_noisy_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_noisy_s0.26_npe.npy')

# %%
PS_auto_cross_noisy_2048 = MCSamples(
    samples=PS_auto_cross_noisy_2048,
    names=labels,
    label="PS auto&cross, noisy, 2048"
)
PS_auto_cross_noisy_1024 = MCSamples(
    samples=PS_auto_cross_noisy_1024,
    names=labels,
    label="PS auto&cross, noisy, 1024"
)
PS_auto_cross_noisy_1024_bar = MCSamples(
    samples=PS_auto_cross_noisy_1024_bar,
    names=labels,
    label="PS auto&cross, noisy, 1024, bar"
)
PS_BNT_auto_cross_noisy_2048 = MCSamples(
    samples=PS_BNT_auto_cross_noisy_2048,
    names=labels,
    label="BNT PS auto&cross, noisy, 2048"
)
PS_BNT_auto_cross_noisy_1024 = MCSamples(
    samples=PS_BNT_auto_cross_noisy_1024,
    names=labels,
    label="BNT PS auto&cross, noisy, 1024"
)

# %% [markdown]
# ## Masked vs Unmasked

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked5000_nobar_1024, PS_auto_cross_masked14000_nobar_1024, PS_auto_cross_masked28000_nobar_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_noisy_1024, PS_auto_cross_masked40000_nobar_1024, PS_auto_cross_masked39000_nobar_1024, PS_auto_cross_masked35000_nobar_1024, PS_auto_cross_masked28000_nobar_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_noisy_1024, PS_auto_cross_masked40000_nobar_1024, PS_auto_cross_masked5000_nobar_1024, PS_auto_cross_masked14000_nobar_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ## Masked (different ell)

# %%
PS_auto_cross_masked_bar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_nobar_1024 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_bar_800 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-800_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
# PS_auto_cross_masked_nobar_800 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-800_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_bar_700 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-700_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_nobar_700 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-700_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_bar_600 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-600_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked_nobar_600 = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-600_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')

# %%
PS_auto_cross_masked_bar_1024 = MCSamples(
    samples=PS_auto_cross_masked_bar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 1024"
)
PS_auto_cross_masked_nobar_1024 = MCSamples(
    samples=PS_auto_cross_masked_nobar_1024,
    names=labels,
    label="PS auto&cross, noisy, masked, no bar, 1024"
)
PS_auto_cross_masked_bar_800 = MCSamples(
    samples=PS_auto_cross_masked_bar_800,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 800"
)
# PS_auto_cross_masked_nobar_800 = MCSamples(
#     samples=PS_auto_cross_masked_nobar_800,
#     names=labels,
#     label="PS auto&cross, noisy, masked, no bar, 800"
# )
PS_auto_cross_masked_bar_700 = MCSamples(
    samples=PS_auto_cross_masked_bar_700,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 700"
)
PS_auto_cross_masked_nobar_700 = MCSamples(
    samples=PS_auto_cross_masked_nobar_700,
    names=labels,
    label="PS auto&cross, noisy, masked, no bar, 700"
)
PS_auto_cross_masked_bar_600 = MCSamples(
    samples=PS_auto_cross_masked_bar_600,
    names=labels,
    label="PS auto&cross, noisy, masked, bar, 600"
)
PS_auto_cross_masked_nobar_600 = MCSamples(
    samples=PS_auto_cross_masked_nobar_600,
    names=labels,
    label="PS auto&cross, noisy, masked, no bar, 600"
)

# %% [markdown]
# ## Tension

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( PS_auto_cross_noisy_1024, PS_auto_cross_noisy_1024_bar )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 46.75, dofs =  6, P = 1.00000
# nsigma = 5.604

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( PS_auto_cross_masked35000_nobar_1024, PS_auto_cross_masked35000_bar_1024 )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 30.94, dofs =  6, P = 0.99997
# nsigma = 4.206

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( PS_auto_cross_masked14000_nobar_1024, PS_auto_cross_masked14000_bar_1024 )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 11.72, dofs =  6, P = 0.93150
# nsigma = 1.822

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( PS_auto_cross_masked5000_nobar_1024, PS_auto_cross_masked5000_bar_1024 )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 3.09, dofs =  6, P = 0.20240
# nsigma = 0.256

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( PS_auto_cross_masked39000_nobar_1024, PS_auto_cross_masked39000_bar_1024 )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 27.99, dofs =  6, P = 0.99991
# nsigma = 3.905

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( PS_auto_cross_masked40000_nobar_1024, PS_auto_cross_masked40000_bar_1024 )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 23.31, dofs =  6, P = 0.99930
# nsigma = 3.390

# %%
plt.plot([5000, 14000, 35000,  42000], [0.256, 1.822, 4.206,  5.604], 'o-')
plt.title('PS')
# Out:
# Text(0.5, 1.0, 'PS')

# %% [markdown]
# # l1

# %%
l1_nobar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12345_noisy_s0.26_new_normalization_npe.npy')
l1_masked14000_nobar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12345_noisy_s0.26_masked_14000sqdeg_new_normalization_npe.npy')
l1_masked35000_nobar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales12345_noisy_s0.26_masked_35000sqdeg_new_normalization_npe.npy')

l1_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bins1234_scales12345_noisy_s0.26_new_normalization_npe.npy')
l1_masked14000_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bins1234_scales1234_noisy_s0.26_masked_14000sqdeg_new_normalization_npe.npy')
l1_masked35000_bar = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bins1234_scales1234_noisy_s0.26_masked_35000sqdeg_new_normalization_npe.npy')

l1_bar_cut = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bins1234_scales2345_noisy_s0.26_new_normalization_npe.npy')
l1_masked14000_bar_cut = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bins1234_scales2345_noisy_s0.26_masked_14000sqdeg_new_normalization_npe.npy')
l1_masked35000_bar_cut = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_baryonified_bins1234_scales234_noisy_s0.26_masked_35000sqdeg_new_normalization_npe.npy')

l1_nobar_cut = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales2345_noisy_s0.26_new_normalization_npe.npy')
l1_masked14000_nobar_cut = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales2345_noisy_s0.26_masked_14000sqdeg_new_normalization_npe.npy')
l1_masked35000_nobar_cut = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_nobaryons_vs_nobaryons_bins1234_scales234_noisy_s0.26_masked_35000sqdeg_new_normalization_npe.npy')

# %%
l1_nobar = MCSamples(
    samples=l1_nobar,
    names=labels,
    label="L1, noisy, no bar"
)
l1_masked14000_nobar = MCSamples(
    samples=l1_masked14000_nobar,
    names=labels,
    label="L1, noisy, masked 14000, no bar"
)
l1_masked35000_nobar = MCSamples(
    samples=l1_masked35000_nobar,
    names=labels,
    label="L1, noisy, masked 35000, no bar"
)

l1_bar = MCSamples(
    samples=l1_bar,
    names=labels,
    label="L1, noisy, bar"
)
l1_masked14000_bar = MCSamples(
    samples=l1_masked14000_bar,
    names=labels,
    label="L1, noisy, masked 14000, bar"
)
l1_masked35000_bar = MCSamples(
    samples=l1_masked35000_bar,
    names=labels,
    label="L1, noisy, masked 35000, bar"
)

l1_bar_cut = MCSamples(
    samples=l1_bar_cut,
    names=labels,
    label="L1, noisy, bar, cut"
)
l1_masked14000_bar_cut = MCSamples(
    samples=l1_masked14000_bar_cut,
    names=labels,   
    label="L1, noisy, masked 14000, bar, cut",
)
l1_masked35000_bar_cut = MCSamples(
    samples=l1_masked35000_bar_cut,
    names=labels,
    label="L1, noisy, masked 35000, bar, cut",
)

l1_nobar_cut = MCSamples(
    samples=l1_nobar_cut,
    names=labels,
    label="L1, noisy, no bar, cut"
)
l1_masked14000_nobar_cut = MCSamples(
    samples=l1_masked14000_nobar_cut,
    names=labels,
    label="L1, noisy, masked 14000, no bar, cut"
)
l1_masked35000_nobar_cut = MCSamples(
    samples=l1_masked35000_nobar_cut,
    names=labels,
    label="L1, noisy, masked 35000, no bar, cut",
)

# %% [markdown]
# ## Masked vs Unmasked

# %% [markdown]
# ### Nobar

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([l1_nobar, l1_masked14000_nobar, l1_masked35000_nobar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([l1_nobar_cut, l1_masked35000_nobar_cut, l1_masked14000_nobar_cut],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Bar

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([l1_bar, l1_masked14000_bar, l1_masked35000_bar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Bar cut

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([l1_bar_cut, l1_masked14000_bar_cut, l1_masked35000_bar_cut],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### Tension

# %% [markdown]
# #### All scales

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( l1_nobar, l1_bar )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 73.88, dofs =  6, P = 1.00000
# nsigma = 7.497

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( l1_masked35000_nobar, l1_masked35000_bar )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 59.86, dofs =  6, P = 1.00000
# nsigma = 6.577

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( l1_masked14000_nobar, l1_masked14000_bar )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 22.36, dofs =  6, P = 0.99896
# nsigma = 3.279

# %% [markdown]
# #### Without first scale

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( l1_nobar_cut, l1_bar_cut )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 1.07, dofs =  6, P = 0.01709
# nsigma = 0.021

# %%
Q_DM, Q_DM_dofs = gaussian_tension.Q_DM( l1_masked35000_nobar_cut, l1_masked35000_bar_cut )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 0.79, dofs =  6, P = 0.00753
# nsigma = 0.009

# %%
_cutQ_DM, Q_DM_dofs = gaussian_tension.Q_DM( l1_masked14000_nobar_cut, l1_masked14000_bar_cut )
Q_DM_P = scipy.stats.chi2.cdf(Q_DM, Q_DM_dofs)
# print everything:
print(f'Q_DM = {Q_DM:.2f}, dofs = {Q_DM_dofs:2}, P = {Q_DM_P:.5f}')
# convert to effective number of sigmas:
Q_DM_nsigma = utilities.from_confidence_to_sigma(Q_DM_P)
# print everything:
print(f'nsigma = {Q_DM_nsigma:.3f}')
# Out:
# Q_DM = 0.79, dofs =  6, P = 0.00753
# nsigma = 0.009

# %% [markdown]
# #

# %% [markdown]
# # PS vs l1

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_noisy_1024, l1_nobar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked_nobar_1024, l1_masked14000_nobar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked35000_nobar_1024, l1_masked35000_nobar],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# # BNT PS

# %%
PS_auto_cross_masked14000_nobar_1024_BNT  = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked14000_nobar_1024_BNT_abs = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_abs_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked5000_nobar_1024_BNT  = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1024_r100_masked_5000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked5000_nobar_1024_BNT_1536  = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_nobaryons_bins1234_l30-1536_r100_masked_5000sqdeg_noisy_s0.26_npe.npy')


PS_auto_cross_masked14000_bar_1024_BNT  = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_14000sqdeg_noisy_s0.26_npe.npy')
PS_auto_cross_masked5000_bar_1024_BNT  = np.load('/home/tersenov/software/bar_impact/outputs/samples/posterior_samples_bnt_ps_auto_cross_nobaryons_vs_baryonified_bins1234_l30-1024_r100_masked_5000sqdeg_noisy_s0.26_npe.npy')

# %%
PS_auto_cross_masked14000_nobar_1024_BNT = MCSamples(
    samples=PS_auto_cross_masked14000_nobar_1024_BNT,
    names=labels,
    label="BNT PS auto&cross, noisy, masked 14000, no bar, 1024"
)
PS_auto_cross_masked5000_nobar_1024_BNT = MCSamples(
    samples=PS_auto_cross_masked5000_nobar_1024_BNT,
    names=labels,
    label="BNT PS auto&cross, noisy, masked 5000, no bar, 1024"
)
PS_auto_cross_masked14000_bar_1024_BNT = MCSamples(
    samples=PS_auto_cross_masked14000_bar_1024_BNT,
    names=labels,
    label="BNT PS auto&cross, noisy, masked 14000, bar, 1024"
)
PS_auto_cross_masked5000_bar_1024_BNT = MCSamples(
    samples=PS_auto_cross_masked5000_bar_1024_BNT,
    names=labels,
    label="BNT PS auto&cross, noisy, masked 5000, bar, 1024"
)
PS_auto_cross_masked14000_nobar_1024_BNT_abs = MCSamples(
    samples=PS_auto_cross_masked14000_nobar_1024_BNT_abs,
    names=labels,
    label="BNT PS auto&cross, noisy, masked 14000, no bar abs, 1024"
)
PS_auto_cross_masked5000_nobar_1024_BNT_1536 = MCSamples(
    samples=PS_auto_cross_masked5000_nobar_1024_BNT_1536,
    names=labels,
    label="BNT PS auto&cross, noisy, masked 5000, no bar, 1536"
)

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked5000_nobar_1024_BNT, PS_auto_cross_masked14000_nobar_1024_BNT],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked5000_bar_1024_BNT, PS_auto_cross_masked14000_bar_1024_BNT],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %% [markdown]
# ### BNT vs noBNT

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked5000_nobar_1024_BNT, PS_auto_cross_masked5000_nobar_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()

# %%
true_params = np.array([[ 2.600e-01,  8.400e-01, -1.000e+00,  6.736e+01,  9.649e-01,
         4.930e-02]])

g = plots.get_subplot_plotter()

g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.99

g.triangle_plot([PS_auto_cross_masked14000_nobar_1024_BNT, PS_auto_cross_masked14000_nobar_1024],
                filled=True,
                markers={
                    label: val for label, val in zip(labels, true_params[0])
                },
                contour_lws=1.1,
                marker_args={'color': 'black',
                             'lw': 1.},
                )

plt.show()
